# %% [markdown]
# - Data that we use should align with the live data feed for executing trades.
# - We might need additional supporting data such as: satellite image, sensor data, web traffic data, customer reviews, etc. But make sure that it is legal to obtain the data.
# - Options:
#     - Yahoo finance
#     - Nasdaq data link
#     - Intrinio
#     - Alpha vantage
#     - CoinGecko

# %%
import pandas as pd
import yfinance as yf
import time

# %%
TICKER_CODE = "BBCA.JK"
START_DATE = "2023-01-01"
END_DATE = "2025-10-22"

# %%
for i in range(3):
    try:
        df = yf.download(
            TICKER_CODE,
            start=START_DATE,
            end=END_DATE,
            timeout=120
        )
        break
    except Exception as e:
        print(f"Attempt {i+1} failed: {e}")
        time.sleep(5)
# Out:
# Failed to get ticker 'BBCA.JK' reason: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['BBCA.JK']: ConnectionError(ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')))
