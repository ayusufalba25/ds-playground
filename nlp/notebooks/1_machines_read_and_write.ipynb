# %% [markdown]
# NLP enables us to process natural language (human language) to:
# 1. Make conclusions
# 2. Infer new facts (???)
# 3. Create meaningful abstraction (???)
# 4. Make conversations -> chatbot

# %% [markdown]
# The natural representation of the MEANING of natural language in the form of vector is called as embedding.

# %%
import torch

print(torch.xpu.is_available())
# Out:
# False
